# %%
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
from textblob import TextBlob
! pip install readability
# Out:
# Requirement already satisfied: readability in c:\users\dhananjay\anaconda3\lib\site-packages (0.3.1)

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
url_id =['https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/ ',
'https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/', 
'https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/ ',
'https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/', 
'https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/',
'https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/', 
'https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/',
'https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/ ',
'https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/ ',
'https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/ ',
'https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/ ',
'https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/',
'https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/',
'https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/ ',
'https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/' ,
'https://insights.blackcoffer.com/evolution-of-advertising-industry/' ,
'https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/' ,
'https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/' ,
'https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/',
'https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/' ,
'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/', 
'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/' ,
'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/' ,
'https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/' ,
'https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/',
'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/' ,
'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/' ,
'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/' ,
'https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/' ,
'https://insights.blackcoffer.com/how-we-forecast-future-technologies/' ,
'https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/' ,
'https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/',
'https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/' ,
'https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/' ,
'https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/' ,
'https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/' ,
'https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/' ,
'https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/' ,
'https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/' ,
'https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/' ,
'https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/' ,
'https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/' ,
'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/' ,
'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-3/',
'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work/',
'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/',
'https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/' , 
'https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/',
'https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/',
'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/' , 
'https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/' ,
'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/',
'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/' ,
'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/' ,
'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/',
'https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/',
'https://insights.blackcoffer.com/covid-19-how-have-countries-been-responding-2/',
'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-2/',
'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-3/',
'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-4/',
'https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/',
'https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/ ',
'https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/' ,
'https://insights.blackcoffer.com/evolution-of-advertising-industry/' ,
'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/', 
'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/' ,
'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/' ,
'https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/' ,
'https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/',
'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/' ,
'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/' ,
'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/' ,
'https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/' ,
'https://insights.blackcoffer.com/how-we-forecast-future-technologies/' ,
'https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/' ,
'https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/',
'https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/' ,
'https://insights.blackcoffer.com/why-scams-like-nirav-modi-happen-with-indian-banks/',
'https://insights.blackcoffer.com/impact-of-covid-19-on-the-global-economy/',
'https://insights.blackcoffer.com/impact-of-covid-19coronavirus-on-the-indian-economy-2/',
'https://insights.blackcoffer.com/impact-of-covid-19-on-the-global-economy-2/',
'https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy-3/',
'https://insights.blackcoffer.com/should-celebrities-be-allowed-to-join-politics/',
'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/',
'https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/ ' ,
'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/ ' ,
'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/ ' ,
'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/' ,
'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/' ,
'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis/' ,
'https://insights.blackcoffer.com/covid-19-how-have-countries-been-responding/' ,
'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-2/' ,
'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-3/' ,
'https://insights.blackcoffer.com/how-prepared-is-india-to-tackle-a-possible-covid-19-outbreak/',
'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work/',
'https://insights.blackcoffer.com/why-scams-like-nirav-modi-happen-with-indian-banks/',
'https://insights.blackcoffer.com/impact-of-covid-19-on-the-global-economy/',
'https://insights.blackcoffer.com/impact-of-covid-19coronavirus-on-the-indian-economy-2/',
'https://insights.blackcoffer.com/impact-of-covid-19-on-the-global-economy-2/',
'https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy-3/',
'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/' ,
'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis/' ,
'https://insights.blackcoffer.com/covid-19-how-have-countries-been-responding/' ,
'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-2/' ,
'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-3/' ,
'https://insights.blackcoffer.com/controversy-as-a-marketing-strategy/',
'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry/',
'https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets/',
'https://insights.blackcoffer.com/what-are-the-key-policies-that-will-mitigate-the-impacts-of-covid-19-on-the-world-of-work/',
'https://insights.blackcoffer.com/marketing-drives-results-with-a-focus-on-problems/',
'https://insights.blackcoffer.com/continued-demand-for-sustainability/',
'https://insights.blackcoffer.com/coronavirus-disease-covid-19-effect-the-impact-and-role-of-mass-media-during-the-pandemic/',
'https://insights.blackcoffer.com/should-people-wear-fabric-gloves-seeking-evidence-regarding-the-differential-transfer-of-covid-19-or-coronaviruses-generally-between-surfaces/',
'https://insights.blackcoffer.com/why-is-there-a-severe-immunological-and-inflammatory-explosion-in-those-affected-by-sarms-covid-19/',
'https://insights.blackcoffer.com/what-do-you-think-is-the-lesson-or-lessons-to-be-learned-with-covid-19/',
'https://insights.blackcoffer.com/coronavirus-the-unexpected-challenge-for-the-european-union/',
'https://insights.blackcoffer.com/industrial-revolution-4-0-pros-and-cons/',
'https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy/',
'https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy-2/',
'https://insights.blackcoffer.com/impact-of-covid-19coronavirus-on-the-indian-economy/',
'https://insights.blackcoffer.com/blockchain-in-fintech/',
'https://insights.blackcoffer.com/blockchain-for-payments/',
'https://insights.blackcoffer.com/the-future-of-investing/',
'https://insights.blackcoffer.com/big-data-analytics-in-healthcare/',
'https://insights.blackcoffer.com/business-analytics-in-the-healthcare-industry/',
'https://insights.blackcoffer.com/challenges-and-opportunities-of-big-data-in-healthcare/ ']

# %%
for i in url_id:
    response = requests.get(i)
    soup = BeautifulSoup(response.content, 'html.parser')
    title_tag = soup.find('h1', class_='tdb-title-text')
    title = title_tag.text.strip() if title_tag else ''
    article_tag = soup.find_all('p', class_="")
    text = ' '.join([p.text.strip() for p in soup])
    text = re.sub('<[^<]+?>', '', text)
    simpleStr = ""
    for p in article_tag:
        import re
        clean = re.compile('<.*?>')
        raw= re.sub(clean, '', str(p))
        simpleStr += raw + " "
    #print(simpleStr)
    #print(' ')
    #print('*'*125)
    import nltk
    sentences = nltk.sent_tokenize(simpleStr)
    #print(sentences)
    #print(' ')
    #print('*'*125)
    total_number_of_sentences = len(sentences)
    print('total number of sentence in url',total_number_of_sentences)
    #print(' ')
    #print('*'*125)
    # Remove Punctuation
    import re 
    corpus = []
    for i in range(len(sentences)):
        rp = re.sub('[^a-zA-Z]',' ', sentences[i])
        corpus.append(rp)
    #print(corpus)
    #Remove stopwords
    corpus=[]
    for i in range(len(sentences)):
        rp = re.sub('[^a-zA-Z]',' ', sentences[i])
        rp = rp.lower()
        rp = rp.split()
        rp = [ word for word in rp if not word in set(stopwords.words('english'))]
        rp = ' '.join(rp)
        corpus.append(rp)
    #print(corpus)
    #print(' ')
    #print('*'*125)
    total_number_of_words = 0
    for text in corpus:
        words = text.split()
        total_number_of_words += len(words)
    print("Total number of words:", total_number_of_words)
    import pandas as pd
    from textblob import TextBlob
    def analyze_sentiment(tweet):
        analysis = TextBlob(tweet)
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
    corpus = pd.DataFrame(corpus, columns=['corpus'])
    corpus['sentiment'] = [str(analyze_sentiment(x)) for x in corpus.corpus]
    #print(corpus.sentiment.value_counts())
    corpus_sentiment = corpus['sentiment'].value_counts()
    positive_score = corpus_sentiment['positive']
    negative_score = corpus_sentiment['negative']
    neutral_score = corpus_sentiment['neutral']
    print('positive score = ',positive_score)
    print('negative score = ',negative_score)
    print('neutral score = ',neutral_score)
    
    Polarity_Score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    print('Polarity Score = ',Polarity_Score)
    
    Subjectivity_Score= (positive_score + negative_score) / (total_number_of_words+0.000001)
    print('Subjective Score = ' , Subjectivity_Score)
    
    Average_Sentence_Length = total_number_of_words/total_number_of_sentences
    print('Average Sentence Length =' ,Average_Sentence_Length)
    
    def count_syllables(word):
        vowels = "aeiouy"
        count = 0
        prev_char = ''
        for char in word:
            if char.lower() in vowels and prev_char not in vowels:
                count += 1
            prev_char = char
        if word.endswith("e"):
            count -= 1
        if count == 0:
            count = 1
        return count
    words = simpleStr.split()
    complex_count = 0
    for word in words:
        if count_syllables(word)>2:
            complex_count += 1
    print("The number of complex words in the text is:", complex_count)
    
    def count_syllables(word):
        vowels = "aeiouy"
        count = 0
        prev_char = ''
        for char in word:
            if char.lower() in vowels and prev_char not in vowels:
                count += 1
            prev_char = char
        if word.endswith("e"):
            count -= 1
        if count == 0:
            count = 1
        return count
    words = simpleStr.split()
    complex_count = 0
    for word in words:
        if count_syllables(word) >= 3:
            complex_count += 1
    total_count = len(words)
    complex_percentage = complex_count / total_count * 100
    print("The percentage of complex words in the text is:", complex_percentage, "%")
    
    Fog_Index = 0.4 * ( Average_Sentence_Length + complex_percentage)
    print('Fog Index = ',  Fog_Index)
    
    Average_Number_of_Words_Per_Sentence = total_number_of_words / total_number_of_sentences
    print('Average Number of Words Per Sentence = ',  Average_Number_of_Words_Per_Sentence )
    
    import readability
    results = readability.getmeasures(corpus,lang='en')
    results
    
    import re
    pattern = r"\b(I|we|my|ours|us)\b"
    total_number_of_personal_pronouns = len(re.findall(pattern, simpleStr, flags=re.IGNORECASE))
    print("The number of personal pronouns in the text is:", total_number_of_personal_pronouns)
    print(' '*125)
    print('*' * 125)
    print(' '*125)
# Out:
# total number of sentence in url 75
# Total number of words: 1151
# positive score =  45
# negative score =  9
# neutral score =  21
# Polarity Score =  0.6666666543209879
# Subjective Score =  0.04691572541536426
# Average Sentence Length = 15.346666666666666
# The number of complex words in the text is: 376
# The percentage of complex words in the text is: 21.206993795826286 %
# Fog Index =  14.62146418499718
# Average Number of Words Per Sentence =  15.346666666666666
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 79
# Total number of words: 750
# positive score =  32
# negative score =  14
# neutral score =  33
# Polarity Score =  0.3913043393194709
# Subjective Score =  0.06133333325155556
# Average Sentence Length = 9.49367088607595
# The number of complex words in the text is: 207
# The percentage of complex words in the text is: 14.775160599571734 %
# Fog Index =  9.707532594259074
# Average Number of Words Per Sentence =  9.49367088607595
# The number of personal pronouns in the text is: 7
#
# *****************************************************************************************************************************
#
# total number of sentence in url 84
# Total number of words: 987
# positive score =  32
# negative score =  19
# neutral score =  33
# Polarity Score =  0.2549019557862362
# Subjective Score =  0.05167173247044404
# Average Sentence Length = 11.75
# The number of complex words in the text is: 349
# The percentage of complex words in the text is: 20.724465558194773 %
# Fog Index =  12.98978622327791
# Average Number of Words Per Sentence =  11.75
# The number of personal pronouns in the text is: 3
#
# *****************************************************************************************************************************
#
# total number of sentence in url 91
# Total number of words: 866
# positive score =  43
# negative score =  12
# neutral score =  36
# Polarity Score =  0.56363635338843
# Subjective Score =  0.06351039253636213
# Average Sentence Length = 9.516483516483516
# The number of complex words in the text is: 212
# The percentage of complex words in the text is: 13.350125944584383 %
# Fog Index =  9.14664378442716
# Average Number of Words Per Sentence =  9.516483516483516
# The number of personal pronouns in the text is: 18
#
# *****************************************************************************************************************************
#
# total number of sentence in url 76
# Total number of words: 930
# positive score =  30
# negative score =  23
# neutral score =  23
# Polarity Score =  0.13207546920612323
# Subjective Score =  0.0569892472505492
# Average Sentence Length = 12.236842105263158
# The number of complex words in the text is: 266
# The percentage of complex words in the text is: 15.7396449704142 %
# Fog Index =  11.190594830270944
# Average Number of Words Per Sentence =  12.236842105263158
# The number of personal pronouns in the text is: 16
#
# *****************************************************************************************************************************
#
# total number of sentence in url 48
# Total number of words: 580
# positive score =  23
# negative score =  9
# neutral score =  16
# Polarity Score =  0.4374999863281255
# Subjective Score =  0.055172413697978595
# Average Sentence Length = 12.083333333333334
# The number of complex words in the text is: 162
# The percentage of complex words in the text is: 15.154349859681945 %
# Fog Index =  10.895073277206112
# Average Number of Words Per Sentence =  12.083333333333334
# The number of personal pronouns in the text is: 12
#
# *****************************************************************************************************************************
#
# total number of sentence in url 36
# Total number of words: 299
# positive score =  13
# negative score =  5
# neutral score =  18
# Polarity Score =  0.4444444197530878
# Subjective Score =  0.060200668694981044
# Average Sentence Length = 8.305555555555555
# The number of complex words in the text is: 96
# The percentage of complex words in the text is: 17.422867513611614 %
# Fog Index =  10.29136922766687
# Average Number of Words Per Sentence =  8.305555555555555
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 35
# Total number of words: 381
# positive score =  18
# negative score =  4
# neutral score =  13
# Polarity Score =  0.6363636074380178
# Subjective Score =  0.05774278200067511
# Average Sentence Length = 10.885714285714286
# The number of complex words in the text is: 70
# The percentage of complex words in the text is: 10.028653295128938 %
# Fog Index =  8.365747032337291
# Average Number of Words Per Sentence =  10.885714285714286
# The number of personal pronouns in the text is: 2
#
# *****************************************************************************************************************************
#
# total number of sentence in url 80
# Total number of words: 1200
# positive score =  52
# negative score =  10
# neutral score =  18
# Polarity Score =  0.6774193439125913
# Subjective Score =  0.05166666662361111
# Average Sentence Length = 15.0
# The number of complex words in the text is: 338
# The percentage of complex words in the text is: 15.735567970204842 %
# Fog Index =  12.294227188081937
# Average Number of Words Per Sentence =  15.0
# The number of personal pronouns in the text is: 11
#
# *****************************************************************************************************************************
#
# total number of sentence in url 90
# Total number of words: 1073
# positive score =  45
# negative score =  17
# neutral score =  28
# Polarity Score =  0.4516128959417275
# Subjective Score =  0.05778191979703455
# Average Sentence Length = 11.922222222222222
# The number of complex words in the text is: 299
# The percentage of complex words in the text is: 16.294277929155314 %
# Fog Index =  11.286600060551017
# Average Number of Words Per Sentence =  11.922222222222222
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 57
# Total number of words: 679
# positive score =  22
# negative score =  9
# neutral score =  26
# Polarity Score =  0.4193548251821024
# Subjective Score =  0.04565537548504363
# Average Sentence Length = 11.912280701754385
# The number of complex words in the text is: 226
# The percentage of complex words in the text is: 19.31623931623932 %
# Fog Index =  12.491408007197482
# Average Number of Words Per Sentence =  11.912280701754385
# The number of personal pronouns in the text is: 10
#
# *****************************************************************************************************************************
#
# total number of sentence in url 80
# Total number of words: 724
# positive score =  24
# negative score =  13
# neutral score =  43
# Polarity Score =  0.2972972892622354
# Subjective Score =  0.05110497230510363
# Average Sentence Length = 9.05
# The number of complex words in the text is: 190
# The percentage of complex words in the text is: 15.741507870753935 %
# Fog Index =  9.916603148301576
# Average Number of Words Per Sentence =  9.05
# The number of personal pronouns in the text is: 6
#
# *****************************************************************************************************************************
#
# total number of sentence in url 60
# Total number of words: 829
# positive score =  30
# negative score =  5
# neutral score =  25
# Polarity Score =  0.7142856938775517
# Subjective Score =  0.04221954156547703
# Average Sentence Length = 13.816666666666666
# The number of complex words in the text is: 251
# The percentage of complex words in the text is: 15.276932440657335 %
# Fog Index =  11.637439642929602
# Average Number of Words Per Sentence =  13.816666666666666
# The number of personal pronouns in the text is: 32
#
# *****************************************************************************************************************************
#
# total number of sentence in url 80
# Total number of words: 863
# positive score =  29
# negative score =  19
# neutral score =  32
# Polarity Score =  0.20833332899305565
# Subjective Score =  0.05561993041063739
# Average Sentence Length = 10.7875
# The number of complex words in the text is: 268
# The percentage of complex words in the text is: 17.527795945062135 %
# Fog Index =  11.326118378024853
# Average Number of Words Per Sentence =  10.7875
# The number of personal pronouns in the text is: 11
#
# *****************************************************************************************************************************
#
# total number of sentence in url 21
# Total number of words: 305
# positive score =  12
# negative score =  5
# neutral score =  4
# Polarity Score =  0.4117646816609011
# Subjective Score =  0.05573770473528621
# Average Sentence Length = 14.523809523809524
# The number of complex words in the text is: 98
# The percentage of complex words in the text is: 19.639278557114228 %
# Fog Index =  13.6652352323695
# Average Number of Words Per Sentence =  14.523809523809524
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 40
# Total number of words: 406
# positive score =  13
# negative score =  4
# neutral score =  23
# Polarity Score =  0.5294117335640156
# Subjective Score =  0.0418719210791332
# Average Sentence Length = 10.15
# The number of complex words in the text is: 156
# The percentage of complex words in the text is: 22.25392296718973 %
# Fog Index =  12.961569186875892
# Average Number of Words Per Sentence =  10.15
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 55
# Total number of words: 763
# positive score =  21
# negative score =  21
# neutral score =  13
# Polarity Score =  0.0
# Subjective Score =  0.05504587148748903
# Average Sentence Length = 13.872727272727273
# The number of complex words in the text is: 209
# The percentage of complex words in the text is: 15.300146412884333 %
# Fog Index =  11.669149474244643
# Average Number of Words Per Sentence =  13.872727272727273
# The number of personal pronouns in the text is: 2
#
# *****************************************************************************************************************************
#
# total number of sentence in url 28
# Total number of words: 397
# positive score =  20
# negative score =  2
# neutral score =  6
# Polarity Score =  0.8181817809917372
# Subjective Score =  0.055415616988877536
# Average Sentence Length = 14.178571428571429
# The number of complex words in the text is: 111
# The percentage of complex words in the text is: 15.568022440392706 %
# Fog Index =  11.898637547585654
# Average Number of Words Per Sentence =  14.178571428571429
# The number of personal pronouns in the text is: 5
#
# *****************************************************************************************************************************
#
# total number of sentence in url 109
# Total number of words: 969
# positive score =  61
# negative score =  8
# neutral score =  40
# Polarity Score =  0.7681159308968706
# Subjective Score =  0.0712074302670718
# Average Sentence Length = 8.889908256880734
# The number of complex words in the text is: 274
# The percentage of complex words in the text is: 14.520402755696873 %
# Fog Index =  9.364124405031044
# Average Number of Words Per Sentence =  8.889908256880734
# The number of personal pronouns in the text is: 10
#
# *****************************************************************************************************************************
#
# total number of sentence in url 43
# Total number of words: 369
# positive score =  22
# negative score =  4
# neutral score =  17
# Polarity Score =  0.6923076656804744
# Subjective Score =  0.07046070441609566
# Average Sentence Length = 8.581395348837209
# The number of complex words in the text is: 109
# The percentage of complex words in the text is: 16.846986089644513 %
# Fog Index =  10.171352575392689
# Average Number of Words Per Sentence =  8.581395348837209
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 16
# Total number of words: 222
# positive score =  6
# negative score =  1
# neutral score =  9
# Polarity Score =  0.7142856122449125
# Subjective Score =  0.03153153138949761
# Average Sentence Length = 13.875
# The number of complex words in the text is: 53
# The percentage of complex words in the text is: 14.520547945205479 %
# Fog Index =  11.358219178082193
# Average Number of Words Per Sentence =  13.875
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 34
# Total number of words: 445
# positive score =  18
# negative score =  6
# neutral score =  10
# Polarity Score =  0.4999999791666675
# Subjective Score =  0.053932584148466106
# Average Sentence Length = 13.088235294117647
# The number of complex words in the text is: 84
# The percentage of complex words in the text is: 10.473815461346634 %
# Fog Index =  9.424820302185713
# Average Number of Words Per Sentence =  13.088235294117647
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 19
# Total number of words: 287
# positive score =  10
# negative score =  3
# neutral score =  6
# Polarity Score =  0.5384614970414233
# Subjective Score =  0.04529616708956039
# Average Sentence Length = 15.105263157894736
# The number of complex words in the text is: 96
# The percentage of complex words in the text is: 20.64516129032258 %
# Fog Index =  14.300169779286927
# Average Number of Words Per Sentence =  15.105263157894736
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 109
# Total number of words: 969
# positive score =  61
# negative score =  8
# neutral score =  40
# Polarity Score =  0.7681159308968706
# Subjective Score =  0.0712074302670718
# Average Sentence Length = 8.889908256880734
# The number of complex words in the text is: 274
# The percentage of complex words in the text is: 14.520402755696873 %
# Fog Index =  9.364124405031044
# Average Number of Words Per Sentence =  8.889908256880734
# The number of personal pronouns in the text is: 10
#
# *****************************************************************************************************************************
#
# total number of sentence in url 43
# Total number of words: 369
# positive score =  22
# negative score =  4
# neutral score =  17
# Polarity Score =  0.6923076656804744
# Subjective Score =  0.07046070441609566
# Average Sentence Length = 8.581395348837209
# The number of complex words in the text is: 109
# The percentage of complex words in the text is: 16.846986089644513 %
# Fog Index =  10.171352575392689
# Average Number of Words Per Sentence =  8.581395348837209
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 16
# Total number of words: 222
# positive score =  6
# negative score =  1
# neutral score =  9
# Polarity Score =  0.7142856122449125
# Subjective Score =  0.03153153138949761
# Average Sentence Length = 13.875
# The number of complex words in the text is: 53
# The percentage of complex words in the text is: 14.520547945205479 %
# Fog Index =  11.358219178082193
# Average Number of Words Per Sentence =  13.875
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 34
# Total number of words: 445
# positive score =  18
# negative score =  6
# neutral score =  10
# Polarity Score =  0.4999999791666675
# Subjective Score =  0.053932584148466106
# Average Sentence Length = 13.088235294117647
# The number of complex words in the text is: 84
# The percentage of complex words in the text is: 10.473815461346634 %
# Fog Index =  9.424820302185713
# Average Number of Words Per Sentence =  13.088235294117647
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 19
# Total number of words: 287
# positive score =  10
# negative score =  3
# neutral score =  6
# Polarity Score =  0.5384614970414233
# Subjective Score =  0.04529616708956039
# Average Sentence Length = 15.105263157894736
# The number of complex words in the text is: 96
# The percentage of complex words in the text is: 20.64516129032258 %
# Fog Index =  14.300169779286927
# Average Number of Words Per Sentence =  15.105263157894736
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 27
# Total number of words: 185
# positive score =  14
# negative score =  1
# neutral score =  12
# Polarity Score =  0.8666666088888928
# Subjective Score =  0.08108108064280498
# Average Sentence Length = 6.851851851851852
# The number of complex words in the text is: 55
# The percentage of complex words in the text is: 14.588859416445624 %
# Fog Index =  8.576284507318992
# Average Number of Words Per Sentence =  6.851851851851852
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 10
# Total number of words: 89
# positive score =  4
# negative score =  2
# neutral score =  4
# Polarity Score =  0.33333327777778704
# Subjective Score =  0.06741572957959854
# Average Sentence Length = 8.9
# The number of complex words in the text is: 31
# The percentage of complex words in the text is: 20.26143790849673 %
# Fog Index =  11.664575163398693
# Average Number of Words Per Sentence =  8.9
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 55
# Total number of words: 407
# positive score =  15
# negative score =  15
# neutral score =  25
# Polarity Score =  0.0
# Subjective Score =  0.07371007352896788
# Average Sentence Length = 7.4
# The number of complex words in the text is: 95
# The percentage of complex words in the text is: 11.889862327909889 %
# Fog Index =  7.715944931163955
# Average Number of Words Per Sentence =  7.4
# The number of personal pronouns in the text is: 19
#
# *****************************************************************************************************************************
#
# total number of sentence in url 9
# Total number of words: 97
# positive score =  6
# negative score =  1
# neutral score =  2
# Polarity Score =  0.7142856122449125
# Subjective Score =  0.07216494770963972
# Average Sentence Length = 10.777777777777779
# The number of complex words in the text is: 19
# The percentage of complex words in the text is: 10.795454545454545 %
# Fog Index =  8.62929292929293
# Average Number of Words Per Sentence =  10.777777777777779
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 31
# Total number of words: 409
# positive score =  12
# negative score =  5
# neutral score =  14
# Polarity Score =  0.4117646816609011
# Subjective Score =  0.041564792074413714
# Average Sentence Length = 13.193548387096774
# The number of complex words in the text is: 126
# The percentage of complex words in the text is: 18.7779433681073 %
# Fog Index =  12.788596702081632
# Average Number of Words Per Sentence =  13.193548387096774
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 5
# Total number of words: 73
# positive score =  2
# negative score =  1
# neutral score =  2
# Polarity Score =  0.33333322222225925
# Subjective Score =  0.04109588984800151
# Average Sentence Length = 14.6
# The number of complex words in the text is: 12
# The percentage of complex words in the text is: 8.275862068965518 %
# Fog Index =  9.150344827586208
# Average Number of Words Per Sentence =  14.6
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 21
# Total number of words: 177
# positive score =  8
# negative score =  4
# neutral score =  9
# Polarity Score =  0.3333333055555579
# Subjective Score =  0.06779660978645984
# Average Sentence Length = 8.428571428571429
# The number of complex words in the text is: 38
# The percentage of complex words in the text is: 10.187667560321715 %
# Fog Index =  7.446495595557258
# Average Number of Words Per Sentence =  8.428571428571429
# The number of personal pronouns in the text is: 6
#
# *****************************************************************************************************************************
#
# total number of sentence in url 73
# Total number of words: 971
# positive score =  37
# negative score =  12
# neutral score =  24
# Polarity Score =  0.5102040712203251
# Subjective Score =  0.05046343970086155
# Average Sentence Length = 13.301369863013699
# The number of complex words in the text is: 364
# The percentage of complex words in the text is: 21.299005266237568 %
# Fog Index =  13.840150051700508
# Average Number of Words Per Sentence =  13.301369863013699
# The number of personal pronouns in the text is: 15
#
# *****************************************************************************************************************************
#
# total number of sentence in url 68
# Total number of words: 876
# positive score =  31
# negative score =  11
# neutral score =  26
# Polarity Score =  0.476190464852608
# Subjective Score =  0.04794520542472008
# Average Sentence Length = 12.882352941176471
# The number of complex words in the text is: 192
# The percentage of complex words in the text is: 11.028144744399771 %
# Fog Index =  9.564199074230498
# Average Number of Words Per Sentence =  12.882352941176471
# The number of personal pronouns in the text is: 19
#
# *****************************************************************************************************************************
#
# total number of sentence in url 81
# Total number of words: 799
# positive score =  20
# negative score =  16
# neutral score =  45
# Polarity Score =  0.11111110802469146
# Subjective Score =  0.04505632034410974
# Average Sentence Length = 9.864197530864198
# The number of complex words in the text is: 187
# The percentage of complex words in the text is: 12.950138504155126 %
# Fog Index =  9.125734414007729
# Average Number of Words Per Sentence =  9.864197530864198
# The number of personal pronouns in the text is: 18
#
# *****************************************************************************************************************************
#
# total number of sentence in url 56
# Total number of words: 352
# positive score =  24
# negative score =  4
# neutral score =  28
# Polarity Score =  0.7142856887755111
# Subjective Score =  0.07954545431947314
# Average Sentence Length = 6.285714285714286
# The number of complex words in the text is: 99
# The percentage of complex words in the text is: 12.359550561797752 %
# Fog Index =  7.458105939004816
# Average Number of Words Per Sentence =  6.285714285714286
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 65
# Total number of words: 654
# positive score =  28
# negative score =  11
# neutral score =  26
# Polarity Score =  0.4358974247205789
# Subjective Score =  0.059633027431753784
# Average Sentence Length = 10.061538461538461
# The number of complex words in the text is: 165
# The percentage of complex words in the text is: 11.785714285714285 %
# Fog Index =  8.7389010989011
# Average Number of Words Per Sentence =  10.061538461538461
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 16
# Total number of words: 226
# positive score =  12
# negative score =  2
# neutral score =  2
# Polarity Score =  0.7142856632653098
# Subjective Score =  0.06194690238076592
# Average Sentence Length = 14.125
# The number of complex words in the text is: 59
# The percentage of complex words in the text is: 12.79826464208243 %
# Fog Index =  10.769305856832972
# Average Number of Words Per Sentence =  14.125
# The number of personal pronouns in the text is: 8
#
# *****************************************************************************************************************************
#
# total number of sentence in url 69
# Total number of words: 929
# positive score =  34
# negative score =  11
# neutral score =  24
# Polarity Score =  0.5111110997530867
# Subjective Score =  0.04843918186389754
# Average Sentence Length = 13.46376811594203
# The number of complex words in the text is: 261
# The percentage of complex words in the text is: 16.508538899430743 %
# Fog Index =  11.988922806149109
# Average Number of Words Per Sentence =  13.46376811594203
# The number of personal pronouns in the text is: 8
#
# *****************************************************************************************************************************
#
# total number of sentence in url 76
# Total number of words: 497
# positive score =  22
# negative score =  15
# neutral score =  39
# Polarity Score =  0.18918918407596802
# Subjective Score =  0.07444667993069079
# Average Sentence Length = 6.5394736842105265
# The number of complex words in the text is: 118
# The percentage of complex words in the text is: 12.065439672801636 %
# Fog Index =  7.441965342804865
# Average Number of Words Per Sentence =  6.5394736842105265
# The number of personal pronouns in the text is: 13
#
# *****************************************************************************************************************************
#
# total number of sentence in url 34
# Total number of words: 444
# positive score =  19
# negative score =  9
# neutral score =  6
# Polarity Score =  0.35714284438775556
# Subjective Score =  0.06306306292102913
# Average Sentence Length = 13.058823529411764
# The number of complex words in the text is: 134
# The percentage of complex words in the text is: 16.983523447401776 %
# Fog Index =  12.016938790725417
# Average Number of Words Per Sentence =  13.058823529411764
# The number of personal pronouns in the text is: 8
#
# *****************************************************************************************************************************
#
# total number of sentence in url 69
# Total number of words: 837
# positive score =  29
# negative score =  21
# neutral score =  19
# Polarity Score =  0.15999999680000007
# Subjective Score =  0.059737156439979504
# Average Sentence Length = 12.130434782608695
# The number of complex words in the text is: 195
# The percentage of complex words in the text is: 12.588766946417044 %
# Fog Index =  9.887680691610298
# Average Number of Words Per Sentence =  12.130434782608695
# The number of personal pronouns in the text is: 6
#
# *****************************************************************************************************************************
#
# total number of sentence in url 76
# Total number of words: 497
# positive score =  22
# negative score =  15
# neutral score =  39
# Polarity Score =  0.18918918407596802
# Subjective Score =  0.07444667993069079
# Average Sentence Length = 6.5394736842105265
# The number of complex words in the text is: 118
# The percentage of complex words in the text is: 12.065439672801636 %
# Fog Index =  7.441965342804865
# Average Number of Words Per Sentence =  6.5394736842105265
# The number of personal pronouns in the text is: 13
#
# *****************************************************************************************************************************
#
# total number of sentence in url 76
# Total number of words: 558
# positive score =  37
# negative score =  4
# neutral score =  35
# Polarity Score =  0.8048780291493164
# Subjective Score =  0.07347670237728189
# Average Sentence Length = 7.342105263157895
# The number of complex words in the text is: 105
# The percentage of complex words in the text is: 9.408602150537634 %
# Fog Index =  6.700282965478213
# Average Number of Words Per Sentence =  7.342105263157895
# The number of personal pronouns in the text is: 5
#
# *****************************************************************************************************************************
#
# total number of sentence in url 43
# Total number of words: 573
# positive score =  20
# negative score =  3
# neutral score =  20
# Polarity Score =  0.7391304026465042
# Subjective Score =  0.040139615985794734
# Average Sentence Length = 13.325581395348838
# The number of complex words in the text is: 87
# The percentage of complex words in the text is: 8.596837944664031 %
# Fog Index =  8.768967736005148
# Average Number of Words Per Sentence =  13.325581395348838
# The number of personal pronouns in the text is: 5
#
# *****************************************************************************************************************************
#
# total number of sentence in url 60
# Total number of words: 621
# positive score =  20
# negative score =  10
# neutral score =  30
# Polarity Score =  0.33333332222222256
# Subjective Score =  0.048309178666168795
# Average Sentence Length = 10.35
# The number of complex words in the text is: 206
# The percentage of complex words in the text is: 19.234360410831002 %
# Fog Index =  11.833744164332401
# Average Number of Words Per Sentence =  10.35
# The number of personal pronouns in the text is: 9
#
# *****************************************************************************************************************************
#
# total number of sentence in url 72
# Total number of words: 512
# positive score =  23
# negative score =  15
# neutral score =  34
# Polarity Score =  0.21052631024930765
# Subjective Score =  0.07421874985504151
# Average Sentence Length = 7.111111111111111
# The number of complex words in the text is: 124
# The percentage of complex words in the text is: 12.362911266201396 %
# Fog Index =  7.789608950925004
# Average Number of Words Per Sentence =  7.111111111111111
# The number of personal pronouns in the text is: 15
#
# *****************************************************************************************************************************
#
# total number of sentence in url 29
# Total number of words: 349
# positive score =  9
# negative score =  8
# neutral score =  12
# Polarity Score =  0.05882352595155729
# Subjective Score =  0.048710601579625784
# Average Sentence Length = 12.03448275862069
# The number of complex words in the text is: 102
# The percentage of complex words in the text is: 15.315315315315313 %
# Fog Index =  10.939919229574402
# Average Number of Words Per Sentence =  12.03448275862069
# The number of personal pronouns in the text is: 5
#
# *****************************************************************************************************************************
#
# total number of sentence in url 11
# Total number of words: 152
# positive score =  6
# negative score =  2
# neutral score =  3
# Polarity Score =  0.4999999375000079
# Subjective Score =  0.05263157860110804
# Average Sentence Length = 13.818181818181818
# The number of complex words in the text is: 42
# The percentage of complex words in the text is: 14.53287197231834 %
# Fog Index =  11.340421516200065
# Average Number of Words Per Sentence =  13.818181818181818
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 24
# Total number of words: 430
# positive score =  13
# negative score =  4
# neutral score =  7
# Polarity Score =  0.5294117335640156
# Subjective Score =  0.039534883628988646
# Average Sentence Length = 17.916666666666668
# The number of complex words in the text is: 130
# The percentage of complex words in the text is: 17.759562841530055 %
# Fog Index =  14.270491803278691
# Average Number of Words Per Sentence =  17.916666666666668
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 56
# Total number of words: 679
# positive score =  21
# negative score =  18
# neutral score =  17
# Polarity Score =  0.0769230749506904
# Subjective Score =  0.05743740786828069
# Average Sentence Length = 12.125
# The number of complex words in the text is: 174
# The percentage of complex words in the text is: 14.463840399002494 %
# Fog Index =  10.635536159600997
# Average Number of Words Per Sentence =  12.125
# The number of personal pronouns in the text is: 6
#
# *****************************************************************************************************************************
#
# total number of sentence in url 194
# Total number of words: 2043
# positive score =  49
# negative score =  24
# neutral score =  121
# Polarity Score =  0.3424657487333459
# Subjective Score =  0.035731766991810195
# Average Sentence Length = 10.530927835051546
# The number of complex words in the text is: 528
# The percentage of complex words in the text is: 15.291051259774111 %
# Fog Index =  10.328791637930264
# Average Number of Words Per Sentence =  10.530927835051546
# The number of personal pronouns in the text is: 2
#
# *****************************************************************************************************************************
# ...
#
# *****************************************************************************************************************************
#
# total number of sentence in url 70
# Total number of words: 1008
# positive score =  42
# negative score =  10
# neutral score =  18
# Polarity Score =  0.6153846035502961
# Subjective Score =  0.05158730153612371
# Average Sentence Length = 14.4
# The number of complex words in the text is: 285
# The percentage of complex words in the text is: 17.18938480096502 %
# Fog Index =  12.635753920386009
# Average Number of Words Per Sentence =  14.4
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 59
# Total number of words: 809
# positive score =  30
# negative score =  10
# neutral score =  19
# Polarity Score =  0.49999998750000035
# Subjective Score =  0.04944375766447002
# Average Sentence Length = 13.711864406779661
# The number of complex words in the text is: 230
# The percentage of complex words in the text is: 17.138599105812222 %
# Fog Index =  12.340185405036754
# Average Number of Words Per Sentence =  13.711864406779661
# The number of personal pronouns in the text is: 8
#
# *****************************************************************************************************************************
#
# total number of sentence in url 27
# Total number of words: 419
# positive score =  11
# negative score =  6
# neutral score =  10
# Polarity Score =  0.2941176297577865
# Subjective Score =  0.040572792265936054
# Average Sentence Length = 15.518518518518519
# The number of complex words in the text is: 167
# The percentage of complex words in the text is: 25.264750378214828 %
# Fog Index =  16.31330755869334
# Average Number of Words Per Sentence =  15.518518518518519
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 13
# Total number of words: 188
# positive score =  6
# negative score =  2
# neutral score =  5
# Polarity Score =  0.4999999375000079
# Subjective Score =  0.04255319126301494
# Average Sentence Length = 14.461538461538462
# The number of complex words in the text is: 58
# The percentage of complex words in the text is: 18.77022653721683 %
# Fog Index =  13.292705999502116
# Average Number of Words Per Sentence =  14.461538461538462
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 14
# Total number of words: 172
# positive score =  7
# negative score =  1
# neutral score =  6
# Polarity Score =  0.7499999062500118
# Subjective Score =  0.046511627636560304
# Average Sentence Length = 12.285714285714286
# The number of complex words in the text is: 17
# The percentage of complex words in the text is: 5.345911949685535 %
# Fog Index =  7.052650494159929
# Average Number of Words Per Sentence =  12.285714285714286
# The number of personal pronouns in the text is: 7
#
# *****************************************************************************************************************************
#
# total number of sentence in url 20
# Total number of words: 190
# positive score =  1
# negative score =  3
# neutral score =  16
# Polarity Score =  -0.49999987500003124
# Subjective Score =  0.021052631468144047
# Average Sentence Length = 9.5
# The number of complex words in the text is: 55
# The percentage of complex words in the text is: 14.102564102564102 %
# Fog Index =  9.441025641025641
# Average Number of Words Per Sentence =  9.5
# The number of personal pronouns in the text is: 5
#
# *****************************************************************************************************************************
#
# total number of sentence in url 7
# Total number of words: 125
# positive score =  3
# negative score =  2
# neutral score =  2
# Polarity Score =  0.199999960000008
# Subjective Score =  0.03999999968
# Average Sentence Length = 17.857142857142858
# The number of complex words in the text is: 35
# The percentage of complex words in the text is: 15.765765765765765 %
# Fog Index =  13.44916344916345
# Average Number of Words Per Sentence =  17.857142857142858
# The number of personal pronouns in the text is: 4
#
# *****************************************************************************************************************************
#
# total number of sentence in url 14
# Total number of words: 135
# positive score =  3
# negative score =  4
# neutral score =  7
# Polarity Score =  -0.1428571224489825
# Subjective Score =  0.05185185146776406
# Average Sentence Length = 9.642857142857142
# The number of complex words in the text is: 45
# The percentage of complex words in the text is: 17.928286852589643 %
# Fog Index =  11.028457598178715
# Average Number of Words Per Sentence =  9.642857142857142
# The number of personal pronouns in the text is: 8
#
# *****************************************************************************************************************************
#
# total number of sentence in url 7
# Total number of words: 92
# positive score =  4
# negative score =  1
# neutral score =  2
# Polarity Score =  0.599999880000024
# Subjective Score =  0.05434782549621929
# Average Sentence Length = 13.142857142857142
# The number of complex words in the text is: 29
# The percentage of complex words in the text is: 18.954248366013072 %
# Fog Index =  12.838842203548086
# Average Number of Words Per Sentence =  13.142857142857142
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 38
# Total number of words: 509
# positive score =  22
# negative score =  9
# neutral score =  7
# Polarity Score =  0.4193548251821024
# Subjective Score =  0.06090373268977656
# Average Sentence Length = 13.394736842105264
# The number of complex words in the text is: 123
# The percentage of complex words in the text is: 13.268608414239482 %
# Fog Index =  10.6653381025379
# Average Number of Words Per Sentence =  13.394736842105264
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 15
# Total number of words: 241
# positive score =  4
# negative score =  8
# neutral score =  3
# Polarity Score =  -0.3333333055555579
# Subjective Score =  0.04979253091372394
# Average Sentence Length = 16.066666666666666
# The number of complex words in the text is: 56
# The percentage of complex words in the text is: 12.121212121212121 %
# Fog Index =  11.275151515151515
# Average Number of Words Per Sentence =  16.066666666666666
# The number of personal pronouns in the text is: 3
#
# *****************************************************************************************************************************
#
# total number of sentence in url 74
# Total number of words: 981
# positive score =  31
# negative score =  7
# neutral score =  36
# Polarity Score =  0.6315789307479229
# Subjective Score =  0.03873598365062591
# Average Sentence Length = 13.256756756756756
# The number of complex words in the text is: 301
# The percentage of complex words in the text is: 16.834451901565995 %
# Fog Index =  12.0364834633291
# Average Number of Words Per Sentence =  13.256756756756756
# The number of personal pronouns in the text is: 1
#
# *****************************************************************************************************************************
#
# total number of sentence in url 33
# Total number of words: 392
# positive score =  17
# negative score =  6
# neutral score =  10
# Polarity Score =  0.4782608487712674
# Subjective Score =  0.05867346923807788
# Average Sentence Length = 11.878787878787879
# The number of complex words in the text is: 112
# The percentage of complex words in the text is: 15.469613259668508 %
# Fog Index =  10.939360455382555
# Average Number of Words Per Sentence =  11.878787878787879
# The number of personal pronouns in the text is: 2
#
# *****************************************************************************************************************************
#
# total number of sentence in url 48
# Total number of words: 547
# positive score =  17
# negative score =  10
# neutral score =  21
# Polarity Score =  0.2592592496570648
# Subjective Score =  0.049360146162047265
# Average Sentence Length = 11.395833333333334
# The number of complex words in the text is: 170
# The percentage of complex words in the text is: 19.187358916478555 %
# Fog Index =  12.233276899924755
# Average Number of Words Per Sentence =  11.395833333333334
# The number of personal pronouns in the text is: 9
#
# *****************************************************************************************************************************
#
# total number of sentence in url 49
# Total number of words: 637
# positive score =  20
# negative score =  12
# neutral score =  17
# Polarity Score =  0.24999999218750027
# Subjective Score =  0.05023547872804478
# Average Sentence Length = 13.0
# The number of complex words in the text is: 171
# The percentage of complex words in the text is: 15.659340659340659 %
# Fog Index =  11.463736263736264
# Average Number of Words Per Sentence =  13.0
# The number of personal pronouns in the text is: 2
#
# *****************************************************************************************************************************
#
# total number of sentence in url 65
# Total number of words: 652
# positive score =  21
# negative score =  12
# neutral score =  32
# Polarity Score =  0.2727272644628102
# Subjective Score =  0.05061349685488727
# Average Sentence Length = 10.03076923076923
# The number of complex words in the text is: 198
# The percentage of complex words in the text is: 17.647058823529413 %
# Fog Index =  11.071131221719458
# Average Number of Words Per Sentence =  10.03076923076923
# The number of personal pronouns in the text is: 2
#
# *****************************************************************************************************************************
#
# total number of sentence in url 25
# Total number of words: 321
# positive score =  12
# negative score =  3
# neutral score =  10
# Polarity Score =  0.5999999600000027
# Subjective Score =  0.046728971817043705
# Average Sentence Length = 12.84
# The number of complex words in the text is: 121
# The percentage of complex words in the text is: 21.645796064400717 %
# Fog Index =  13.794318425760288
# Average Number of Words Per Sentence =  12.84
# The number of personal pronouns in the text is: 0
#
# *****************************************************************************************************************************
#
# total number of sentence in url 65
# Total number of words: 583
# positive score =  34
# negative score =  12
# neutral score =  19
# Polarity Score =  0.47826085916824224
# Subjective Score =  0.07890222971028778
# Average Sentence Length = 8.96923076923077
# The number of complex words in the text is: 178
# The percentage of complex words in the text is: 17.29834791059281 %
# Fog Index =  10.507031471929432
# Average Number of Words Per Sentence =  8.96923076923077
# The number of personal pronouns in the text is: 8
#
# *****************************************************************************************************************************
